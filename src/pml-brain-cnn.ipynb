# %%
# Brain Tumor Detection
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

import tensorflow as tf
import keras
import cv2 as cv
from tensorflow.keras.preprocessing.image import load_img, ImageDataGenerator
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Conv2D, MaxPool2D,GlobalAveragePooling2D,Flatten,Dense,BatchNormalization,Dropout
from tensorflow.keras.optimizers import Adam

# %%
data = '../data/images/'

# %%
# shape of an image
im = cv.imread('../data/images/yes/yes1.jpg')
print(im.shape)
# Out:
# (218, 180, 3)

# %%
datagen = ImageDataGenerator(
rescale=1./255)

# %%
height, width = 128,128


df_train=tf.keras.utils.image_dataset_from_directory(
    '../data/images/',
    batch_size = 20,
    image_size = (height,width)
    )
d
df_validate  = tf.keras.utils.image_dataset_from_directory(
    '../data/images/',
    batch_size=3,
    image_size=(height,width)
)
# Out:
# Found 253 files belonging to 2 classes.
# Found 253 files belonging to 2 classes.

# %%
df_train.class_names
# Out:
# ['no', 'yes']

# %%
df_validate.class_names
# Out:
# ['no', 'yes']

# %%
class_names = ['no','yes']
plt.figure(figsize=(10,10))  
for images, labels in df_train.take(1):
  for i in range(9):
    ax  = plt.subplot(3,3,i+1)
    plt.imshow(images[i].numpy().astype('uint8'))
    plt.title(class_names[labels[i]])
    plt.axis('off')
