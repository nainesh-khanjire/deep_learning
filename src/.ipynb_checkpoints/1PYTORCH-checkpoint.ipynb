# %%
import torch

# %%
x = torch.rand(2)
x
# Out:
# tensor([0.4317, 0.3318])

# %%
y  = torch.empty(2,4)
y
# Out:
# tensor([[2.6446e+20, 1.3096e-11, 2.1686e-04, 8.2656e-10],
#         [4.1538e+21, 4.1298e-05, 4.3721e-05, 3.2799e-09]])

# %%
a = torch.ones(2,3,dtype = torch.int32)
a.type()
# Out:
# 'torch.IntTensor'

# %%
a.size()
# Out:
# torch.Size([2, 3])
