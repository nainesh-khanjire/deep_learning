# %%
# cnn architecture
#importing packages
import tensorflow as tf
import keras
from keras.models import Sequential,Model
from keras.layers import Conv2D,Dense,activation,Flatten,MaxPool2D,AveragePooling2D,GlobalAveragePooling2D,ZeroPadding2D,Input
from tensorflow.keras.utils import load_img
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import img_to_array
from keras import optimizers

# %%
img = image.load_img('../data/dog.jpg',target_size = (100,100))
img
# Out:
# <PIL.Image.Image image mode=RGB size=100x100>

# %%
img = image.img_to_array(img)

# %%
print(img.shape)
# Out:
# (100, 100, 3)

# %%
model = Sequential()
model.add(Conv2D(input_shape=(10,10,3),filters=10,kernel_size =(3,3),strides=(1,1),padding ='same'))

# %%
model.output_shape
# Out:
# (None, 10, 10, 10)
